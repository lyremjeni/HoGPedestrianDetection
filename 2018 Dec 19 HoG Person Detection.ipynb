# %%
import cv2
import time

hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
cap = cv2.VideoCapture("/path/to/test/video")
while True:
    r, frame = cap.read()
    if r:
        start_time = time.time()
        frame = cv2.resize(frame,(1280, 720)) # Downscale to improve frame rate
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY) # HOG needs a grayscale image

        rects, weights = hog.detectMultiScale(gray_frame)
        
        # Measure elapsed time for detections
        end_time = time.time()
        print("Elapsed time:", end_time-start_time)
        
        for i, (x, y, w, h) in enumerate(rects):
            if weights[i] < 0.7:
                continue
            cv2.rectangle(frame, (x,y), (x+w,y+h),(0,255,0),2)

        cv2.imshow("preview", frame)
    k = cv2.waitKey(1)
    if k & 0xFF == ord("q"): # Exit condition
        break
        
"""
https://gist.github.com/madhawav/a951f3790987532d32126a5f437ca28a


"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-d3a4f6102d04> in <module>()
#      24
#      25         cv2.imshow("preview", frame)
# ---> 26     k = cv2.waitKey(1)
#      27     if k & 0xFF == ord("q"): # Exit condition
#      28         break
#
# KeyboardInterrupt:

# %%
import cv2
import time

hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
cap = cv2.VideoCapture(0)
while True:
    r, frame = cap.read()
    if r:
        start_time = time.time()
        frame = cv2.resize(frame,(1080, 720)) # Downscale to improve frame rate
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY) # HOG needs a grayscale image

        rects, weights = hog.detectMultiScale(gray_frame)
        
        # Measure elapsed time for detections
        end_time = time.time()
        print("Elapsed time:", end_time-start_time)
        
        for i, (x, y, w, h) in enumerate(rects):
            if weights[i] < 0.7:
                continue
            cv2.rectangle(frame, (x,y), (x+w,y+h),(0,255,0),2)

        cv2.imshow("preview", frame)
    k = cv2.waitKey(1)
    if k & 0xFF == ord("q"): # Exit condition
        break
        
"""
https://gist.github.com/madhawav/a951f3790987532d32126a5f437ca28a


"""
# Out:
# Elapsed time: 1.9136645793914795
# Elapsed time: 1.4720923900604248
# Elapsed time: 1.2362394332885742
# Elapsed time: 1.0323622226715088
# Elapsed time: 0.8464810848236084
# Elapsed time: 0.814495325088501
# Elapsed time: 0.6905746459960938
# Elapsed time: 0.6126236915588379
# Elapsed time: 0.4617133140563965
# Elapsed time: 0.39475584030151367
# Elapsed time: 0.45072245597839355
# Elapsed time: 0.4577183723449707
# Elapsed time: 0.4826998710632324
# Elapsed time: 0.4667034149169922
# Elapsed time: 0.46271395683288574
# Elapsed time: 0.4537181854248047
# Elapsed time: 0.4497213363647461
# Elapsed time: 0.4477217197418213
# Elapsed time: 0.4517180919647217
# Elapsed time: 0.46671080589294434
# Elapsed time: 0.43872737884521484
# Elapsed time: 0.48469996452331543
# Elapsed time: 0.43872761726379395
# Elapsed time: 0.45471668243408203
# Elapsed time: 0.4417266845703125
# Elapsed time: 0.4777030944824219
# Elapsed time: 0.44272851943969727
# Elapsed time: 0.47070837020874023
# ...

# %%
import cv2
import time
from imutils.object_detection import non_max_suppression
import numpy as np

hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
cap = cv2.VideoCapture(0)
while True:
    r, frame = cap.read()
    if r:
        start_time = time.time()
        frame = cv2.resize(frame,(1080, 720)) # Downscale to improve frame rate
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY) # HOG needs a grayscale image

        rects, weights = hog.detectMultiScale(gray_frame)
        
        # Measure elapsed time for detections
        end_time = time.time()
        print("Elapsed time:", end_time-start_time)
        
        for i, (x, y, w, h) in enumerate(rects):
            if weights[i] < 0.7:
                continue
            cv2.rectangle(frame, (x,y), (x+w,y+h),(0,255,0),2)
            
        orig = frame.copy()
        rects = np.array([[x, y, x + w, y + h] for (x, y, w, h) in rects])
        pick = non_max_suppression(rects, probs=None, overlapThresh=0.65)

        for (xA, yA, xB, yB) in pick:
            cv2.rectangle(frame, (xA, yA), (xB, yB), (0, 255, 0), 2)
            
        cv2.imshow("preview", orig)
        cv2.imshow("preview 2", frame)
        
    k = cv2.waitKey(1)
    if k & 0xFF == ord("q"): # Exit condition
        break
        
"""
https://gist.github.com/madhawav/a951f3790987532d32126a5f437ca28a


"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8ab72c77d48e> in <module>()
#      34         cv2.imshow("preview 2", frame_orig)
#      35
# ---> 36     k = cv2.waitKey(1)
#      37     if k & 0xFF == ord("q"): # Exit condition
#      38         break
#
# KeyboardInterrupt:

# %%
cap.release()

# %%
## NICE PARAMETERS: stride: (6,6), padding: (20,20), scale=1.05 
import cv2
import time
from imutils.object_detection import non_max_suppression
import numpy as np

hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor.getDefaultPeopleDetector())
cap = cv2.VideoCapture(0)
try:
    while True:
        r, frame_orig = cap.read()
        if r:
            start_time = time.time()
            frame = cv2.resize(frame_orig,(640,480)) # Downscale to improve frame rate
            gray_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY) # HOG needs a grayscale image

    #         rects, weights = hog.detectMultiScale(gray_frame, winStride=(4, 4), scale=1.0)
            rects, weights = hog.detectMultiScale(cv2.UMat(gray_frame), winStride=(6,6), padding=(20,20), scale=1.05)

    #         Measure elapsed time for detections
            end_time = time.time()
    #         print("Elapsed time:", end_time-start_time)

            for i, (x, y, w, h) in enumerate(rects):
                print(x,y,weights[i])
                if weights[i] < 0.7:
                    continue
                cv2.rectangle(frame, (x,y), (x+w,y+h),(0,255,0),2)

            rects = np.array([[x, y, (x + w), (y + h)] for (x, y, w, h) in rects])
            pick = non_max_suppression(rects, probs=None, overlapThresh=0.25)

            for (xA, yA, xB, yB) in pick:
                cv2.rectangle(frame, (xA, yA), (xB, yB), (0, 255, 0), 2)


            cv2.imshow("preview 2", frame)

        k = cv2.waitKey(1)
        if k & 0xFF == ord("q"): # Exit condition
            break
except:
    cap.release()
            
"""
January 23, 2019
"""
# Out:
# '\nJanuary 23, 2019\n'

# %%
cv2.ocl.setUseOpenCL(True)
cv2.__version__
# Out:
# '3.3.1'
